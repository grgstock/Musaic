# %%
import pandas as pd

# %%
tags = pd.read_pickle('tags_200000.pkl')

# %%
tags.head()
# Out:
#          track_name artist_name  \
# 0             Creep   Radiohead
# 1      Karma Police   Radiohead
# 2      No Surprises   Radiohead
# 3  Paranoid Android   Radiohead
# 4      High and Dry   Radiohead
#
#                                                 tags  \
# 0  [{'count': 100, 'name': 'alternative', 'url': ...
# 1  [{'count': 100, 'name': 'alternative', 'url': ...
# 2  [{'count': 100, 'name': 'alternative', 'url': ...
# 3  [{'count': 100, 'name': 'alternative', 'url': ...
# 4  [{'count': 100, 'name': 'alternative', 'url': ...
#
#                                            tags_list
# 0  [alternative, rock, alternative rock, radiohea...
# 1  [alternative, alternative rock, rock, radiohea...
# 2  [alternative, alternative rock, radiohead, roc...
# 3  [alternative, alternative rock, rock, radiohea...
# 4  [alternative, rock, alternative rock, radiohea...

# %%
tags_for_word_cloud = tags['tags'][0]
tags_for_word_cloud
# Out:
# [{'count': 100,
#   'name': 'alternative',
#   'url': 'https://www.last.fm/tag/alternative'},
#  {'count': 91, 'name': 'rock', 'url': 'https://www.last.fm/tag/rock'},
#  {'count': 82,
#   'name': 'alternative rock',
#   'url': 'https://www.last.fm/tag/alternative+rock'},
#  {'count': 64,
#   'name': 'radiohead',
#   'url': 'https://www.last.fm/tag/radiohead'},
#  {'count': 49, 'name': 'indie', 'url': 'https://www.last.fm/tag/indie'},
#  {'count': 29, 'name': '90s', 'url': 'https://www.last.fm/tag/90s'},
#  {'count': 22, 'name': 'british', 'url': 'https://www.last.fm/tag/british'},
#  {'count': 16, 'name': 'britpop', 'url': 'https://www.last.fm/tag/britpop'},
#  {'count': 14, 'name': 'creep', 'url': 'https://www.last.fm/tag/creep'},
#  {'count': 14,
#   'name': 'indie rock',
#   'url': 'https://www.last.fm/tag/indie+rock'},
#  {'count': 13, 'name': 'sad', 'url': 'https://www.last.fm/tag/sad'},
#  {'count': 9,
#   'name': 'melancholy',
#   'url': 'https://www.last.fm/tag/melancholy'},
# ...

# %%
tag_string = ''
for tag in tags_for_word_cloud:
    tag_string += tag['count']*(tag['name'] + ' ')
tag_string
# Out:
# "alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative a
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat"

wc = WordCloud(width = 300, height = 300).generate(tag_string)

# Remove the axis and display the data as image
plt.axis("off")
#plt.imshow(wc, interpolation = "bilinear")
plt.imshow(wc)

# %%
#tags_for_word_cloud_df = pd.DataFrame(tags_for_word_cloud)
#tags_for_word_cloud_df

# %%
tags_for_word_cloud_df.iloc[0]['count']*(tags_for_word_cloud_df.iloc[0]['name']+' ')
# Out:
# 'alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative a
# ...

# %%
text_for_word_cloud = ''
for i in tags_for_word_cloud_df.index:
    text_for_word_cloud += (tags_for_word_cloud_df.iloc[i]['count']*(tags_for_word_cloud_df.iloc[i]['name']+' '))
text_for_word_cloud
# Out:
# "alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative alternative a
# ...

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat"

wc = WordCloud(width = 300, height = 300, repeat = False).generate(text_for_word_cloud)

# Remove the axis and display the data as image
plt.axis("off")
plt.imshow(wc, interpolation = "bilinear")

# plt.show()

# %%
def make_word_cloud(tags):
